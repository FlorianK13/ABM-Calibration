# %% [markdown]
# # 1) Introduction
#
# In the following code, we want to understand a new way of calibrating an agent-based model of Innovation Diffusion. Therefore we will implement a toy model together with its gradients and fit it to the adoption data of small-scale Photovoltaic installations in Germany. Of course, **the general framework is applicable to many other problems in the field of technology or behavioural adoption.**

# %%
import numpy as np
import matplotlib.pyplot as pl
import pandas as pd

# %% [markdown]
# # 2) Data preparation
# In the first part of the code, we will **prepare the data we need for our model.** First we will load the pandas dataframe *Countypd*, which already contains most of the info we need:
#
# 1) The name of the county
# 2) The identification key
# 3) The number of the agents that live in the county
# 4) The incoming radiation (We will not use this directly, but it is part of the average earning for installing PV)
# 5) The population density of the county
# 6) The mean income tax (without units)
#
# These explanatory variables will not be able to reproduce the real data set of PV installtions in a good way, but we won't care about that since we're only interested in calibrating a toy model.

# %%
Countypd=pd.read_csv("Data/PV_Dataframe.csv").drop("Unnamed: 0",axis=1)
Countypd
# Out:
#                         county  county key  state  number agents  radiation  \
# 0         Freiburg im Breisgau        8311    8.0        16410.0     1182.4
# 1       Dillingen an der Donau        9773    9.0        26614.0     1215.4
# 2                     Nürnberg        9564    9.0        50926.0     1186.8
# 3    Neumarkt in der Oberpfalz        9373    9.0        33915.0     1197.2
# 4                    Rosenheim        9163    9.0         7858.0     1236.8
# ..                         ...         ...    ...            ...        ...
# 396     Altmarkkreis Salzwedel       15081   15.0        24213.0     1109.0
# 397          Anhalt-Bitterfeld       15082   15.0        40902.0     1127.4
# 398                      Börde       15083   15.0        48260.0     1121.0
# 399              Mittelsachsen       14522   14.0        67223.0     1129.2
# 400                     Erfurt       16051   16.0        20311.0     1111.0
#
#      population density  mean income tax
# 0                  1511         7.271844
# 1                   122         6.642851
# 2                  2780         6.738487
# 3                   100         6.664490
# 4                  1707         7.013568
# ..                  ...              ...
# 396                  36         4.251962
# 397                 109         3.963499
# 398                  72         5.050583
# 399                 144         4.127533
# 400                 793         5.209551
#
# [401 rows x 7 columns]

# %% [markdown]
#
#
# Finally, some of the data from the county dataframe is transferred to numpy arrays and normalized.

# %%
PopDensity=np.array(Countypd["population density"]).astype(float)
PopDensity-=PopDensity.min()
PopDensity/=PopDensity.max()

Income=np.array(Countypd["mean income tax"]).astype(float)
Income-=Income.min()
Income/=Income.max()

# %% [markdown]
# The next data we load in is the *Earning matrix*, **which is the normalized earning an agent expects** when installing a 1 kWp PV system. It has different entries for each of the 401 counties and varies over the 18 steps in time. For simplicity, it was pre-calculated and depends on
# 1) The average yearly solar irradiation in county c
# 2) The Feed in Tarrif at time t
# 3) The average capital cost for installing 1 kWp of PV
# 4) The lending and deposit interest rates at time t
# 5) The self-consumption ratio

# %%
Earning=np.load("Data/Earning.npy")
print(f"The shape of the Earning matrix is {Earning.shape}")
print(f"The largest entry is {Earning.max()}, the smallest is {Earning.min()}.")
pl.errorbar(np.arange(18),Earning.mean(axis=1),Earning.var(axis=1)**0.5)
pl.ylabel("Normalized earning for installing PV at time t")
pl.xlabel("t")
pl.show()
# Out:
# The shape of the Earning matrix is (18, 401)
# The largest entry is 1.0, the smallest is 0.0.

# %% [markdown]
# Now we need the **Agent matrix to store all info about the individual agents** we need. The agent matrix consists of three columns. The first column is an identiciation number for each agent. The second column is the number of the county the agent lives in. The third column stores the info if the agent has adopted to the new technology and is either a 1 (adopted) or a 0 (not adopted). This third column will be updated at each timestep of the simulation.
#
# Note that the variable *Agent_Scale* shrinks down the model to achieve a faster computation. With the choosen value of 0.005, we do not use the original number of ~1.5e7 agents owning a house in Germany, but only 0.5% of that. Therefore, each agent in the simulation represents 200 agents in reality and the model has 79835 agents.

# %%
from CreateData_GIT import MakeAgentArray

Agent_Scale=0.005
Agent_Array=MakeAgentArray(Countypd,Agent_Scale)

print(Agent_Array.shape)
print(Agent_Array[1000])
# Out:
# (79835, 3)
# [1000    7    0]

# %% [markdown]
# At last, we need the **data set we want to model**, namely the number of new adopters between 2000 and 2019 in each county.

# %%
from CreateData_GIT import Load_PVData
Y,Y_kummulative=Load_PVData()
pl.plot(Y.sum(axis=1),label="New installations per year")
pl.plot(Y_kummulative.sum(axis=1),label="Total number of installations")
pl.legend()
pl.show()
print(f"The shape of the PV Dataset is {Y.shape}")
# Out:
# The shape of the PV Dataset is (19, 401)

# %% [markdown]
# # 3) Defining the model
#
# For detailed information about the model, we refer to the work "Efficiently Calibrating Agent-based Models of Innovation Diffusion".
#
# First we define a **linear utility**. This utility is the sum over the fitting parameters *params_i* times the explanatory variables *X_i*. The higher the value of the utility becomes, the more likely is an adoption of the agent.

# %%
def utility_func(params,X):
    utility=0.
    for i in range(len(params)):
        utility+=params[i]*X[i]
    return utility

# %% [markdown]
# Then we define the **function F, which maps the utility to an adoption probability** in [0,1]. Since we want to model a threshold adoption, the probability to adopt is 1 if the utility is positive and it is 0 if the utility is negative:

# %%
def F(utility):
    p_adopt=utility>0
    return p_adopt

# %% [markdown]
# One part of the explanatory data X should be some sort of opinion variable that reflects the opinion of agent i about adopting. This induces interaction among agents, e.g. if one chooses ideas like the *Relative Agreement model* [1,2]. In this toy model however, we draw a random initial opinion for each agent and change it randomly over time, where positive opinion changes are more likely than negative changes. This simplified opinion model has no interaction among agents and is much faster in terms of computation.
#
# For each agent at every time t, the Opinion lies between -1 and 1.

# %%
from CreateData_GIT import SimpleOpinionStep
Opinion=np.zeros((17,len(Agent_Array)))
Opinion[0]=2*np.random.beta(2,8,size=len(Agent_Array))-1
pl.hist(Opinion[0],bins=100,label="t=0")
for t in range(1,17):
    Opinion=SimpleOpinionStep(Opinion,t)
    pl.hist(Opinion[t],bins=100,label="t="+str(t))
pl.ylabel(r"$ \# agents\ with\ opinion\ o_i$")
pl.xlabel(r"$o_i$")
pl.legend(ncol=2,bbox_to_anchor=(1,1))
pl.show()
pl.plot(Opinion.transpose()[100])
pl.title("Opinion of one agent over time")
pl.ylabel(r"$o_i$")
pl.xlabel(r"$t$")
pl.show()

# %% [markdown]
# Finally we reached the point where we **define the actual model**. The model function needs an array of four values as *params* and the number of years *Timesteps* as a whole number. The output is an array of the same shape as the PV installation array *Y*. It stands for the number of new adopters in each county for each point in time.

# %%
def Model(params,Timesteps,Agent_Array,Countypd=Countypd,utility_func=utility_func,F=F,
          PopDensity=PopDensity,Agent_Scale=Agent_Scale,
          Income=Income,Earning=Earning):
    
    """Generate the part of X that is time independant"""
    CountyofAgent=Agent_Array.transpose()[1]
    X0=PopDensity[CountyofAgent]
    X1=Income[CountyofAgent]
    
    """Generate an initial opinion"""
    Opinion=np.zeros((Timesteps,len(Agent_Array)))
    Opinion[0]=2*np.random.beta(2,8,size=len(Agent_Array))-1
    
    """Generate an individual threshold for each agent"""
    threshold=np.random.beta(5,2,size=len(Agent_Array))
    
    """Define the PV_adopters matrix, which counts the number of new adopters at time t in county c"""
    PV_adopters=np.zeros((Timesteps,len(Countypd)))
    
    """Agents_where is a matrix, that has a 1 at place (county,agent) 
    if the agent lives in that county and a 0 if not. It is used to make the algorithm more efficient later."""
    Agents_where=np.zeros((len(Countypd),len(Agent_Array))).astype(bool)
    for i in range(len(Countypd)):
        Agents_where[i]=Agent_Array.transpose()[1]==i
    
    for t in range(1,Timesteps):
        """Generate the part of X that is time dependant"""
        Opinion=SimpleOpinionStep(Opinion,t)
        X2=(Opinion[t]+1)/2
        X3=Earning[t][CountyofAgent]
        
        X=np.array([X0,X1,X2,X3])
        
        utility=utility_func(params,X)
        p_adopt=F(utility-threshold)
        """Update the adoption variable within the Agent matrix"""
        Agent_Array[np.where(p_adopt==1)[0],2]=1
        """Count the number of new adopters"""
        PV_adopters[t]=np.stack((Agent_Array.transpose()[2],)*len(Countypd)).sum(axis=1,where=Agents_where)-PV_adopters[:t].sum(axis=0)
        
        print(f"New adopters at time {t}: {(PV_adopters[t]/Agent_Scale).sum()}")
    PV_adopters/=Agent_Scale
    
    print(f"Total number of adopters: {(PV_adopters).sum()}")
    return PV_adopters

# %% [markdown]
# Now we can run the model for the first time with some initial parameters.

# %%
"""reset Agent_Array"""
Agent_Array=MakeAgentArray(Countypd,Agent_Scale)

"""Run the model once"""
params=np.array([-.3,.3,.3,.3])
Timesteps=17
Y_tilde=Model(params,Timesteps,Agent_Array)
print(f"The shape of the output is {Y_tilde.shape}")

pl.plot(Y_tilde.cumsum(axis=0).sum(axis=1),label="Initial model with some start parameters")
pl.plot(Y_kummulative.sum(axis=1),label="Real dataset")
pl.legend()
pl.plot()
pl.show()
# Out:
# New adopters at time 1: 47200.0
# New adopters at time 2: 0.0
# New adopters at time 3: 9000.0
# New adopters at time 4: 247400.0
# New adopters at time 5: 0.0
# New adopters at time 6: 400.0
# New adopters at time 7: 14400.0
# New adopters at time 8: 0.0
# New adopters at time 9: 354200.0
# New adopters at time 10: 0.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 672600.0
# The shape of the output is (17, 401)

# %% [markdown]
# # 4) Implementing the gradients
# To calibrate the model, we have to introduce a **cost function C**. Here we use the sum over the squared residuals.

# %%
"""reset Agent_Array"""
Agent_Array=MakeAgentArray(Countypd,Agent_Scale)

Timesteps=17
def Costfunction(params,Agent_Array,Y=Y[:Timesteps],Model=Model,Timesteps=Timesteps):
    Y_tilde=Model(params,Timesteps,Agent_Array)
    residuals=(Y-Y_tilde)**2
    return residuals.sum()

print(f"The value of the cost function is {Costfunction(params,Agent_Array)}")
# Out:
# New adopters at time 1: 49400.0
# New adopters at time 2: 0.0
# New adopters at time 3: 7800.0
# New adopters at time 4: 256400.0
# New adopters at time 5: 0.0
# New adopters at time 6: 1600.0
# New adopters at time 7: 14600.0
# New adopters at time 8: 0.0
# New adopters at time 9: 367600.0
# New adopters at time 10: 0.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 697400.0
# The value of the cost function is 1051617292.0

# %% [markdown]
# An intuitive approach for calibrating agent-based adoption models is the use of black-box optimization algorithms that do not need gradients. The disatvantage of those algorithms is their slow convergence. Especially when using many free parameters, black-box optimization is not able to find a good solution within an acceptable time.
# Hence we will implement the gradients calculated in the paper "Efficiently Calibrating Agent-based Models of Innovation Diffusion".
#
# First, we have to modify the utility function and the F function from above. They now also return their gradients. (Note, that for *F_threshold_wgrad()* the gradient would actually be the delta distribution, but this will kill all gradients, hence we use the gradient to be =1)

# %%
def utility_func_wgrad(params,X):
    utility=0.
    for i in range(len(params)):
        utility+=params[i]*X[i]
    
    grad=X
    return utility,grad

def F_threshold_wgrad(utility):
    p_adopt=utility>0
    grad=np.ones(len(utility))
    return p_adopt,grad

def F_gaussian_wgrad(utility,sigma=1):
    p_adopt=0.5*(1+specialfunc.erf(utility/(2**0.5*sigma)))
    grad=1/(2*sigma**2)**0.5*np.exp(-1*utility**2/(2*sigma**2))
    return p_adopt,grad

# %% [markdown]
# Note that only the parts commented with *NEW* are added to the already defined *Model()*-function.

# %%
def Model_with_gradients(params,Timesteps,Countypd=Countypd,Agent_Array=Agent_Array,utility_func=utility_func_wgrad,
                         F=F_threshold_wgrad,PopDensity=PopDensity,Agent_Scale=Agent_Scale,Income=Income,Earning=Earning):
    
    """Generate the part of X that is time independant"""
    CountyofAgent=Agent_Array.transpose()[1]
    X0=PopDensity[CountyofAgent]
    X1=Income[CountyofAgent]
    
    """Generate an initial opinion"""
    Opinion=np.zeros((Timesteps,len(Agent_Array)))
    Opinion[0]=2*np.random.beta(2,8,size=len(Agent_Array))-1
    
    """Generate an individual threshold for each agent"""
    threshold=np.random.beta(5,2,size=len(Agent_Array))
    
    """Define the PV_adopters matrix, which counts the number of new adopters at time t in county c"""
    PV_adopters=np.zeros((Timesteps,len(Countypd)))
    
    """Agents_where is a matrix, that has a 1 in at place (county,agent) 
    if the agent lives in that county and a 0 if not. It is used to make the algorithm more efficient later."""
    Agents_where=np.zeros((len(Countypd),len(Agent_Array))).astype(bool)
    for i in range(len(Countypd)):
        Agents_where[i]=Agent_Array.transpose()[1]==i
        
    """NEW: Define the gradient matrices"""
    Grad_f_times_X=np.zeros((len(params),Timesteps,len(Countypd)))
    Grad_2_sum=np.zeros((len(params),Timesteps,len(Countypd)))
    Grad_temp_timesum=np.zeros((len(params),Timesteps,len(Agent_Array)))
    Grad_state1=np.zeros((16,Timesteps,len(Countypd)))
    Grad_state_sum=np.zeros((16,Timesteps,len(Countypd)))
    Grad_state_temp_timesum=np.zeros((16,Timesteps,len(Agent_Array)))
    Grad_prod_temp=np.zeros((Timesteps,len(Agent_Array)))
    Grad_prod_temp[0]=np.ones(len(Agent_Array))
    
    
    for t in range(1,Timesteps):
        """Generate the part of X that is time dependant"""
        Opinion=SimpleOpinionStep(Opinion,t)
        X2=(Opinion[t]+1)/2
        X3=Earning[t][CountyofAgent]
        
        X=np.array([X0,X1,X2,X3])
        
        utility,grad_utility=utility_func(params,X)
        p_adopt,grad_adopt=F(utility-threshold)
        
        """NEW: COMPUTE THE GRADIENTS"""
        
        epsilon=1e-8
        """Product part of the gradient"""
        Grad_prod_temp[t]=1-p_adopt
        Grad_prod=Grad_prod_temp[:t].prod(axis=0)
        
        for n in range(len(params)):
            """First Summand within the gradients"""
            grad_temp=grad_adopt*grad_utility[n]*Grad_prod
            Grad_f_times_X[n][t]=np.stack((grad_temp,)*len(Countypd)).sum(axis=1,where=Agents_where)
            """"Second Summand within the gradients"""
            Grad_temp_timesum[n][t]=grad_adopt*grad_utility[n]/(1-p_adopt+epsilon)
            Grad_2_sum_temp=Grad_temp_timesum[n][:t].sum(axis=0)*p_adopt*Grad_prod
            Grad_2_sum[n][t]=np.stack((Grad_2_sum_temp,)*len(Countypd)).sum(axis=1,where=Agents_where)
        
        
        
        """END OF: COMPUTE THE GRADIENTS"""
        
        """Update the adoption variable within the Agent matrix"""
        Agent_Array[np.where(p_adopt==1)[0],2]=1
        
        """Count the number of new adopters"""
        PV_adopters[t]=np.stack((Agent_Array.transpose()[2],)*len(Countypd)).sum(axis=1,where=Agents_where)-PV_adopters[:t].sum(axis=0)
        
        print(f"New adopters at time {t}: {(PV_adopters[t]/Agent_Scale).sum()}")
    
    """NEW: substract the two gradient parts from each other to get the final gradient"""
    Grad=Grad_f_times_X-Grad_2_sum
    
    PV_adopters/=Agent_Scale
    
    print(f"Total number of adopters: {(PV_adopters).sum()}")
    return PV_adopters,Grad

# %% [markdown]
# The new *Costfunction_with_Gradients* has the summed residuals as well as the gradients as its output.

# %%
def Costfunction_with_Gradients(params,Agent_Array,Y=Y[:Timesteps],Model=Model,Timesteps=Timesteps):
    Y_tilde,Grad_Y=Model_with_gradients(params,Timesteps,Agent_Array=Agent_Array)
    residuals=(Y-Y_tilde)**2
    
    """NEW: Calculate the gradients of the Cost function"""
    Grad=np.zeros(len(params))
    for n in range(len(params)):
        Grad_temp=(Y-Y_tilde)*Grad_Y[n]
        Grad[n]=-2*Grad_temp.sum()
    
    return residuals.sum(),Grad

# %%
"""reset Agent_Array"""
Agent_Array=MakeAgentArray(Countypd,Agent_Scale)

Costfunction_with_Gradients(params,Agent_Array)
# Out:
# New adopters at time 1: 46400.0
# New adopters at time 2: 0.0
# New adopters at time 3: 6200.0
# New adopters at time 4: 248200.0
# New adopters at time 5: 0.0
# New adopters at time 6: 1400.0
# New adopters at time 7: 17400.0
# New adopters at time 8: 0.0
# New adopters at time 9: 367000.0
# New adopters at time 10: 0.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 686600.0
# (964856892.0,
#  array([-19728660.4464565 , -28150926.11825032, -64086002.76819374,
#            725385.506216  ]))

# %% [markdown]
# # 5) Calibrating the model
# Now that we can calculate the gradients of the cost function with respect to the free parameters, we can use gradient-based optimizers for the model calibration. This has a huge advantage compared to use black-box optimizers, namely the relatively fast convergence even for many free parameters.
#
# Here we will use adam [3] as our optimizer of choice, but note that we could actually use any gradient-based algorithm, even simple ones such as gradient descent.

# %%
def adam(params,grad_params,mt,vt,n,lr=0.05, beta=(0.3, 0.5),eps=1e-10):
    m_new=beta[0]*mt+(1-beta[0])*grad_params
    v_new=beta[1]*vt+(1-beta[1])*grad_params**2
    m_corr=m_new/(1-beta[0]**n)
    v_corr=v_new/(1-beta[1]**n)
    params_new=params-lr*m_corr/(v_corr**0.5+eps)
    print(params)
    print(-lr*m_corr/(v_corr**0.5+eps))
    return params_new,m_new,v_new

# %%
OptimizationSteps=40
mt=0
vt=0
#params=np.array([-.5,.5,.5,.5])
params=np.random.uniform(0.,1.,size=4)
c_list=[]
    
for n in range(1,OptimizationSteps):
    """reset Agent_Array"""
    Agent_Array=MakeAgentArray(Countypd,Agent_Scale)
    
    c,grad=Costfunction_with_Gradients(params,Agent_Array)
    c_list.append(c)
    params,mt,vt=adam(params,grad,mt,vt,n)   
    if len(c_list)>1:
        pl.plot(c_list)
        pl.yscale("log")
        pl.show()
# Out:
# New adopters at time 1: 4691800.0
# New adopters at time 2: 0.0
# New adopters at time 3: 175400.0
# New adopters at time 4: 6622200.0
# New adopters at time 5: 0.0
# New adopters at time 6: 0.0
# New adopters at time 7: 28600.0
# New adopters at time 8: 0.0
# New adopters at time 9: 2854800.0
# New adopters at time 10: 0.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 14372800.0
# [0.89101853 0.98641242 0.33359622 0.73783639]
# [-0.05  0.05  0.05 -0.05]
# New adopters at time 1: 4726600.0
# New adopters at time 2: 0.0
# New adopters at time 3: 195800.0
# New adopters at time 4: 6183200.0
# New adopters at time 5: 0.0
# New adopters at time 6: 200.0
# New adopters at time 7: 46000.0
# New adopters at time 8: 0.0
# New adopters at time 9: 2852000.0
# New adopters at time 10: 0.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 14003800.0
# [0.84101853 1.03641242 0.38359622 0.68783639]
# [-0.05019307  0.03371663  0.0475418  -0.05105778]
# New adopters at time 1: 4655200.0
# New adopters at time 2: 0.0
# New adopters at time 3: 215000.0
# New adopters at time 4: 5738000.0
# New adopters at time 5: 0.0
# New adopters at time 6: 800.0
# New adopters at time 7: 74200.0
# New adopters at time 8: 0.0
# New adopters at time 9: 2809800.0
# New adopters at time 10: 0.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 13493000.0
# [0.79082546 1.07012904 0.43113802 0.63677861]
# [-0.05030484 -0.01898621  0.04316546 -0.05212634]
# New adopters at time 1: 4332000.0
# New adopters at time 2: 0.0
# New adopters at time 3: 220600.0
# New adopters at time 4: 5235400.0
# New adopters at time 5: 0.0
# New adopters at time 6: 2200.0
# New adopters at time 7: 106600.0
# New adopters at time 8: 0.0
# New adopters at time 9: 2858200.0
# New adopters at time 10: 0.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 12755000.0
# [0.74052063 1.05114283 0.47430347 0.58465226]
# [-0.05018723 -0.04454253  0.03912621 -0.05211854]
# New adopters at time 1: 3879600.0
# New adopters at time 2: 0.0
# New adopters at time 3: 222800.0
# New adopters at time 4: 4732800.0
# New adopters at time 5: 0.0
# New adopters at time 6: 8000.0
# New adopters at time 7: 151800.0
# New adopters at time 8: 0.0
# New adopters at time 9: 2874600.0
# New adopters at time 10: 0.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 11869600.0
# [0.6903334  1.0066003  0.51342968 0.53253372]
# [-0.04982712 -0.05135733  0.03463673 -0.05212759]
# New adopters at time 1: 3420000.0
# New adopters at time 2: 0.0
# New adopters at time 3: 238800.0
# New adopters at time 4: 4067000.0
# New adopters at time 5: 0.0
# New adopters at time 6: 20400.0
# New adopters at time 7: 174000.0
# New adopters at time 8: 0.0
# New adopters at time 9: 2736600.0
# New adopters at time 10: 0.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 10656800.0
# [0.64050628 0.95524297 0.54806641 0.48040613]
# [-0.04949328 -0.05348384  0.02028405 -0.05230298]
# New adopters at time 1: 2934400.0
# New adopters at time 2: 400.0
# New adopters at time 3: 226000.0
# New adopters at time 4: 3407000.0
# New adopters at time 5: 0.0
# New adopters at time 6: 34800.0
# New adopters at time 7: 192800.0
# New adopters at time 8: 0.0
# New adopters at time 9: 2520800.0
# New adopters at time 10: 0.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 9316200.0
# [0.59101299 0.90175913 0.56835046 0.42810315]
# [-0.0490604  -0.05374353 -0.01225102 -0.05219105]
# New adopters at time 1: 2393000.0
# New adopters at time 2: 400.0
# New adopters at time 3: 191400.0
# New adopters at time 4: 2659600.0
# New adopters at time 5: 0.0
# New adopters at time 6: 39600.0
# New adopters at time 7: 205600.0
# New adopters at time 8: 0.0
# New adopters at time 9: 2192200.0
# New adopters at time 10: 400.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 7682200.0
# [0.54195259 0.84801559 0.55609944 0.37591209]
# [-0.04783861 -0.05343375 -0.04220837 -0.05160585]
# New adopters at time 1: 1729600.0
# New adopters at time 2: 400.0
# New adopters at time 3: 144200.0
# New adopters at time 4: 1954400.0
# New adopters at time 5: 0.0
# New adopters at time 6: 39400.0
# New adopters at time 7: 159400.0
# New adopters at time 8: 0.0
# New adopters at time 9: 1750800.0
# New adopters at time 10: 1000.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 5779200.0
# [0.49411398 0.79458184 0.51389107 0.32430625]
# [-0.04558766 -0.05184627 -0.0501322  -0.05006951]
# New adopters at time 1: 1245200.0
# New adopters at time 2: 600.0
# New adopters at time 3: 101400.0
# New adopters at time 4: 1327000.0
# New adopters at time 5: 0.0
# New adopters at time 6: 36000.0
# New adopters at time 7: 128400.0
# New adopters at time 8: 0.0
# New adopters at time 9: 1230200.0
# New adopters at time 10: 1000.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 4069800.0
# [0.44852632 0.74273557 0.46375887 0.27423674]
# [-0.04416525 -0.05034981 -0.05104984 -0.04746208]
# New adopters at time 1: 840000.0
# New adopters at time 2: 800.0
# New adopters at time 3: 70200.0
# New adopters at time 4: 832600.0
# New adopters at time 5: 0.0
# New adopters at time 6: 27600.0
# New adopters at time 7: 86000.0
# New adopters at time 8: 0.0
# New adopters at time 9: 798800.0
# New adopters at time 10: 1000.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 0.0
# New adopters at time 16: 0.0
# Total number of adopters: 2657000.0
# [0.40436108 0.69238576 0.41270903 0.22677466]
# [-0.04348293 -0.04707276 -0.04632212 -0.04284602]
# New adopters at time 1: 570800.0
# New adopters at time 2: 1000.0
# New adopters at time 3: 41800.0
# New adopters at time 4: 497800.0
# New adopters at time 5: 0.0
# New adopters at time 6: 19000.0
# New adopters at time 7: 58200.0
# New adopters at time 8: 200.0
# New adopters at time 9: 480000.0
# New adopters at time 10: 1800.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 200.0
# New adopters at time 16: 0.0
# Total number of adopters: 1670800.0
# [0.36087815 0.645313   0.36638691 0.18392864]
# [-0.04229843 -0.04190907 -0.03586373 -0.03553349]
# New adopters at time 1: 370200.0
# New adopters at time 2: 1000.0
# New adopters at time 3: 28400.0
# New adopters at time 4: 287600.0
# New adopters at time 5: 0.0
# New adopters at time 6: 12400.0
# New adopters at time 7: 42400.0
# New adopters at time 8: 800.0
# New adopters at time 9: 292600.0
# New adopters at time 10: 3400.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 200.0
# New adopters at time 16: 0.0
# Total number of adopters: 1039000.0
# [0.31857972 0.60340393 0.33052317 0.14839515]
# [-0.03977737 -0.03406927 -0.01272119 -0.02453197]
# New adopters at time 1: 271200.0
# New adopters at time 2: 1200.0
# New adopters at time 3: 22000.0
# New adopters at time 4: 177400.0
# New adopters at time 5: 0.0
# New adopters at time 6: 14600.0
# New adopters at time 7: 28800.0
# New adopters at time 8: 800.0
# New adopters at time 9: 195600.0
# New adopters at time 10: 4200.0
# New adopters at time 11: 0.0
# New adopters at time 12: 0.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 400.0
# New adopters at time 16: 1600.0
# Total number of adopters: 717800.0
# [0.27880235 0.56933466 0.31780198 0.12386318]
# [-0.03632322 -0.02459697  0.0202409  -0.01067507]
# New adopters at time 1: 222800.0
# New adopters at time 2: 2200.0
# New adopters at time 3: 21000.0
# New adopters at time 4: 152400.0
# New adopters at time 5: 0.0
# New adopters at time 6: 19800.0
# New adopters at time 7: 24400.0
# New adopters at time 8: 2600.0
# New adopters at time 9: 163000.0
# New adopters at time 10: 6600.0
# New adopters at time 11: 0.0
# New adopters at time 12: 200.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 1400.0
# New adopters at time 16: 2600.0
# Total number of adopters: 619000.0
# [0.24247913 0.54473769 0.33804288 0.11318812]
# [-0.03524235 -0.0178576   0.03945646  0.00060563]
# New adopters at time 1: 199000.0
# New adopters at time 2: 2400.0
# New adopters at time 3: 24600.0
# New adopters at time 4: 154200.0
# New adopters at time 5: 0.0
# New adopters at time 6: 21000.0
# New adopters at time 7: 29600.0
# New adopters at time 8: 4200.0
# New adopters at time 9: 171600.0
# New adopters at time 10: 7200.0
# New adopters at time 11: 0.0
# New adopters at time 12: 800.0
# New adopters at time 13: 0.0
# New adopters at time 14: 0.0
# New adopters at time 15: 4200.0
# New adopters at time 16: 5200.0
# Total number of adopters: 624000.0
# [0.20723678 0.5268801  0.37749934 0.11379375]
# [-0.03524827 -0.01417004  0.04627482  0.00757027]
# New adopters at time 1: 216600.0
# New adopters at time 2: 4000.0
# New adopters at time 3: 27800.0
# New adopters at time 4: 184800.0
# New adopters at time 5: 0.0
# New adopters at time 6: 31000.0
# New adopters at time 7: 43800.0
# New adopters at time 8: 4800.0
# New adopters at time 9: 199000.0
# New adopters at time 10: 10600.0
# New adopters at time 11: 0.0
# New adopters at time 12: 400.0
# New adopters at time 13: 200.0
# New adopters at time 14: 200.0
# New adopters at time 15: 5000.0
# New adopters at time 16: 7000.0
# Total number of adopters: 735200.0
# [0.17198851 0.51271006 0.42377416 0.12136402]
# [-0.03969134 -0.02561471  0.04443517 -0.00018254]
# New adopters at time 1: 201000.0
# New adopters at time 2: 3200.0
# New adopters at time 3: 34800.0
# New adopters at time 4: 181000.0
# New adopters at time 5: 0.0
# New adopters at time 6: 32200.0
# New adopters at time 7: 51200.0
# New adopters at time 8: 8800.0
# New adopters at time 9: 232200.0
# New adopters at time 10: 15000.0
# New adopters at time 11: 0.0
# New adopters at time 12: 3000.0
# New adopters at time 13: 600.0
# New adopters at time 14: 1800.0
# New adopters at time 15: 14200.0
# New adopters at time 16: 14000.0
# Total number of adopters: 793000.0
# [0.13229717 0.48709535 0.46820933 0.12118148]
# [-0.04185007 -0.03419641  0.04280303 -0.01279728]
# New adopters at time 1: 173000.0
# New adopters at time 2: 5800.0
# New adopters at time 3: 27600.0
# New adopters at time 4: 154400.0
# New adopters at time 5: 400.0
# New adopters at time 6: 36400.0
# New adopters at time 7: 47600.0
# New adopters at time 8: 13400.0
# New adopters at time 9: 193200.0
# New adopters at time 10: 23000.0
# New adopters at time 11: 200.0
# New adopters at time 12: 5000.0
# New adopters at time 13: 1800.0
# New adopters at time 14: 5800.0
# New adopters at time 15: 25000.0
# New adopters at time 16: 26200.0
# Total number of adopters: 738800.0
# [0.0904471  0.45289894 0.51101236 0.1083842 ]
# [-0.04070657 -0.03290101  0.04630825 -0.00607679]
# New adopters at time 1: 158600.0
# New adopters at time 2: 9200.0
# New adopters at time 3: 32600.0
# New adopters at time 4: 142800.0
# New adopters at time 5: 2600.0
# New adopters at time 6: 42200.0
# New adopters at time 7: 57200.0
# New adopters at time 8: 17800.0
# New adopters at time 9: 198200.0
# New adopters at time 10: 30800.0
# New adopters at time 11: 400.0
# New adopters at time 12: 9800.0
# New adopters at time 13: 4400.0
# New adopters at time 14: 11400.0
# New adopters at time 15: 31200.0
# New adopters at time 16: 38400.0
# Total number of adopters: 787600.0
# [0.04974052 0.41999793 0.55732062 0.10230741]
# [-0.0397532  -0.03766033  0.04493136 -0.01106848]
# New adopters at time 1: 152000.0
# New adopters at time 2: 11600.0
# New adopters at time 3: 29200.0
# New adopters at time 4: 142800.0
# New adopters at time 5: 6600.0
# New adopters at time 6: 51000.0
# New adopters at time 7: 59000.0
# New adopters at time 8: 22000.0
# New adopters at time 9: 180800.0
# New adopters at time 10: 38800.0
# New adopters at time 11: 3200.0
# New adopters at time 12: 19800.0
# New adopters at time 13: 9600.0
# New adopters at time 14: 16800.0
# New adopters at time 15: 50200.0
# New adopters at time 16: 46000.0
# Total number of adopters: 839400.0
# [0.00998733 0.3823376  0.60225198 0.09123893]
# [-0.04127683 -0.04379824  0.03992492 -0.02588847]
# New adopters at time 1: 125400.0
# New adopters at time 2: 12400.0
# New adopters at time 3: 29600.0
# New adopters at time 4: 98600.0
# New adopters at time 5: 12800.0
# New adopters at time 6: 49600.0
# New adopters at time 7: 52400.0
# New adopters at time 8: 29400.0
# New adopters at time 9: 127800.0
# New adopters at time 10: 49400.0
# New adopters at time 11: 10000.0
# New adopters at time 12: 36600.0
# New adopters at time 13: 19600.0
# New adopters at time 14: 37200.0
# New adopters at time 15: 69400.0
# New adopters at time 16: 65200.0
# Total number of adopters: 825400.0
# [-0.0312895   0.33853936  0.6421769   0.06535046]
# [-0.0363792  -0.03546201  0.04160426  0.012589  ]
# New adopters at time 1: 138200.0
# New adopters at time 2: 17200.0
# New adopters at time 3: 36000.0
# New adopters at time 4: 120200.0
# New adopters at time 5: 11600.0
# New adopters at time 6: 58000.0
# New adopters at time 7: 61800.0
# New adopters at time 8: 31200.0
# New adopters at time 9: 169000.0
# New adopters at time 10: 49400.0
# New adopters at time 11: 14000.0
# New adopters at time 12: 36600.0
# New adopters at time 13: 21600.0
# New adopters at time 14: 40400.0
# New adopters at time 15: 69000.0
# New adopters at time 16: 71600.0
# Total number of adopters: 945800.0
# [-0.0676687   0.30307735  0.68378116  0.07793946]
# [-0.04302472 -0.04883789  0.02094304 -0.0321075 ]
# New adopters at time 1: 115200.0
# New adopters at time 2: 15200.0
# New adopters at time 3: 22000.0
# New adopters at time 4: 62800.0
# New adopters at time 5: 19800.0
# New adopters at time 6: 40600.0
# New adopters at time 7: 54800.0
# New adopters at time 8: 39400.0
# New adopters at time 9: 99800.0
# New adopters at time 10: 47800.0
# New adopters at time 11: 27400.0
# New adopters at time 12: 46000.0
# New adopters at time 13: 36600.0
# New adopters at time 14: 51400.0
# New adopters at time 15: 75400.0
# New adopters at time 16: 73000.0
# Total number of adopters: 827200.0
# [-0.11069342  0.25423946  0.7047242   0.04583196]
# [-0.02815151 -0.02022728  0.04222744  0.03280369]
# New adopters at time 1: 140000.0
# New adopters at time 2: 14800.0
# New adopters at time 3: 40000.0
# New adopters at time 4: 115000.0
# New adopters at time 5: 14400.0
# New adopters at time 6: 61600.0
# New adopters at time 7: 63000.0
# New adopters at time 8: 40000.0
# New adopters at time 9: 178000.0
# New adopters at time 10: 63600.0
# New adopters at time 11: 15600.0
# New adopters at time 12: 46600.0
# New adopters at time 13: 28600.0
# New adopters at time 14: 51400.0
# New adopters at time 15: 81400.0
# New adopters at time 16: 85200.0
# Total number of adopters: 1039200.0
# [-0.13884494  0.23401218  0.74695163  0.07863565]
# [-0.03985552 -0.0464556  -0.00440073 -0.03059242]
# New adopters at time 1: 106000.0
# New adopters at time 2: 17200.0
# New adopters at time 3: 24200.0
# New adopters at time 4: 65400.0
# New adopters at time 5: 20000.0
# New adopters at time 6: 43800.0
# New adopters at time 7: 47400.0
# New adopters at time 8: 37200.0
# New adopters at time 9: 103200.0
# New adopters at time 10: 52200.0
# New adopters at time 11: 25800.0
# New adopters at time 12: 48400.0
# New adopters at time 13: 37400.0
# New adopters at time 14: 62000.0
# New adopters at time 15: 88600.0
# New adopters at time 16: 78400.0
# Total number of adopters: 857200.0
# [-0.17870046  0.18755658  0.74255091  0.04804323]
# [-0.02360171 -0.01074736  0.03427894  0.02503223]
# New adopters at time 1: 125400.0
# New adopters at time 2: 17400.0
# New adopters at time 3: 30800.0
# New adopters at time 4: 100800.0
# New adopters at time 5: 18600.0
# New adopters at time 6: 67400.0
# New adopters at time 7: 61600.0
# New adopters at time 8: 44800.0
# New adopters at time 9: 163600.0
# New adopters at time 10: 67400.0
# New adopters at time 11: 17600.0
# New adopters at time 12: 51000.0
# New adopters at time 13: 35400.0
# New adopters at time 14: 51000.0
# New adopters at time 15: 95600.0
# New adopters at time 16: 89600.0
# Total number of adopters: 1038000.0
# [-0.20230217  0.17680922  0.77682984  0.07307546]
# [-0.03315861 -0.04025467 -0.01254345 -0.02391055]
# New adopters at time 1: 96800.0
# New adopters at time 2: 16800.0
# New adopters at time 3: 23000.0
# New adopters at time 4: 58200.0
# New adopters at time 5: 21200.0
# New adopters at time 6: 46000.0
# New adopters at time 7: 48200.0
# New adopters at time 8: 33200.0
# New adopters at time 9: 111400.0
# New adopters at time 10: 54600.0
# New adopters at time 11: 24400.0
# New adopters at time 12: 49000.0
# New adopters at time 13: 43800.0
# New adopters at time 14: 61200.0
# New adopters at time 15: 76400.0
# New adopters at time 16: 73600.0
# Total number of adopters: 837800.0
# [-0.23546078  0.13655455  0.7642864   0.04916491]
# [0.0122297  0.0135515  0.04038255 0.03275802]
# New adopters at time 1: 132200.0
# New adopters at time 2: 21400.0
# New adopters at time 3: 37000.0
# New adopters at time 4: 111200.0
# New adopters at time 5: 17400.0
# New adopters at time 6: 72600.0
# New adopters at time 7: 69400.0
# New adopters at time 8: 43600.0
# New adopters at time 9: 183800.0
# New adopters at time 10: 70200.0
# New adopters at time 11: 21200.0
# New adopters at time 12: 57800.0
# New adopters at time 13: 33200.0
# New adopters at time 14: 56800.0
# New adopters at time 15: 94400.0
# New adopters at time 16: 100400.0
# Total number of adopters: 1122600.0
# [-0.22323109  0.15010605  0.80466895  0.08192294]
# [-0.0213831  -0.03948218 -0.02533921 -0.03296041]
# New adopters at time 1: 99600.0
# New adopters at time 2: 17600.0
# New adopters at time 3: 23400.0
# New adopters at time 4: 62800.0
# New adopters at time 5: 21600.0
# New adopters at time 6: 40600.0
# New adopters at time 7: 50200.0
# New adopters at time 8: 40200.0
# New adopters at time 9: 111600.0
# New adopters at time 10: 52800.0
# New adopters at time 11: 31000.0
# New adopters at time 12: 52000.0
# New adopters at time 13: 46000.0
# New adopters at time 14: 56400.0
# New adopters at time 15: 81400.0
# New adopters at time 16: 87800.0
# Total number of adopters: 875000.0
# [-0.24461419  0.11062387  0.77932974  0.04896252]
# [0.01480269 0.00220049 0.02155318 0.01701406]
# New adopters at time 1: 106200.0
# New adopters at time 2: 18600.0
# New adopters at time 3: 33400.0
# New adopters at time 4: 86400.0
# New adopters at time 5: 20800.0
# New adopters at time 6: 64000.0
# New adopters at time 7: 57600.0
# New adopters at time 8: 41600.0
# New adopters at time 9: 140200.0
# New adopters at time 10: 66600.0
# New adopters at time 11: 23400.0
# New adopters at time 12: 58800.0
# New adopters at time 13: 41000.0
# New adopters at time 14: 60600.0
# New adopters at time 15: 90800.0
# New adopters at time 16: 101000.0
# Total number of adopters: 1011000.0
# [-0.2298115   0.11282436  0.80088292  0.06597658]
# [-0.01087787 -0.02879318 -0.01086467 -0.0084907 ]
# New adopters at time 1: 96400.0
# New adopters at time 2: 17000.0
# New adopters at time 3: 27800.0
# New adopters at time 4: 67400.0
# New adopters at time 5: 22400.0
# New adopters at time 6: 46200.0
# New adopters at time 7: 53000.0
# New adopters at time 8: 35600.0
# New adopters at time 9: 118000.0
# New adopters at time 10: 54000.0
# New adopters at time 11: 25800.0
# New adopters at time 12: 55000.0
# New adopters at time 13: 40200.0
# New adopters at time 14: 54600.0
# New adopters at time 15: 91200.0
# New adopters at time 16: 86600.0
# Total number of adopters: 891200.0
# [-0.24068937  0.08403118  0.79001825  0.05748588]
# [0.03276678 0.01440882 0.03223309 0.0303898 ]
# New adopters at time 1: 139800.0
# New adopters at time 2: 22200.0
# New adopters at time 3: 40600.0
# New adopters at time 4: 126600.0
# New adopters at time 5: 16600.0
# New adopters at time 6: 74200.0
# New adopters at time 7: 77000.0
# New adopters at time 8: 41000.0
# New adopters at time 9: 205000.0
# New adopters at time 10: 73600.0
# New adopters at time 11: 19400.0
# New adopters at time 12: 52200.0
# New adopters at time 13: 36000.0
# New adopters at time 14: 49200.0
# New adopters at time 15: 111200.0
# New adopters at time 16: 89800.0
# Total number of adopters: 1174400.0
# [-0.20792259  0.09844     0.82225134  0.08787569]
# [-0.0401086  -0.04430833 -0.03861866 -0.04182308]
# New adopters at time 1: 79000.0
# New adopters at time 2: 15400.0
# New adopters at time 3: 21200.0
# New adopters at time 4: 58200.0
# New adopters at time 5: 19800.0
# New adopters at time 6: 38000.0
# New adopters at time 7: 46000.0
# New adopters at time 8: 33600.0
# New adopters at time 9: 93400.0
# New adopters at time 10: 51200.0
# New adopters at time 11: 29000.0
# New adopters at time 12: 50800.0
# New adopters at time 13: 40200.0
# New adopters at time 14: 52400.0
# New adopters at time 15: 81000.0
# New adopters at time 16: 83200.0
# Total number of adopters: 792400.0
# [-0.2480312   0.05413168  0.78363268  0.04605261]
# [0.02312173 0.0184922  0.02789649 0.02139389]
# New adopters at time 1: 105000.0
# New adopters at time 2: 17000.0
# New adopters at time 3: 38000.0
# New adopters at time 4: 88400.0
# New adopters at time 5: 19800.0
# New adopters at time 6: 63200.0
# New adopters at time 7: 65400.0
# New adopters at time 8: 44000.0
# New adopters at time 9: 145200.0
# New adopters at time 10: 61400.0
# New adopters at time 11: 24600.0
# New adopters at time 12: 56000.0
# New adopters at time 13: 40400.0
# New adopters at time 14: 63600.0
# New adopters at time 15: 98000.0
# New adopters at time 16: 85600.0
# Total number of adopters: 1015600.0
# [-0.22490947  0.07262387  0.81152918  0.0674465 ]
# [-0.01163452 -0.01148902 -0.00640844 -0.00860529]
# New adopters at time 1: 93200.0
# New adopters at time 2: 18600.0
# New adopters at time 3: 30200.0
# New adopters at time 4: 69400.0
# New adopters at time 5: 20200.0
# New adopters at time 6: 52400.0
# New adopters at time 7: 54000.0
# New adopters at time 8: 42000.0
# New adopters at time 9: 119600.0
# New adopters at time 10: 61600.0
# New adopters at time 11: 25400.0
# New adopters at time 12: 52400.0
# New adopters at time 13: 45000.0
# New adopters at time 14: 62200.0
# New adopters at time 15: 97200.0
# New adopters at time 16: 86600.0
# Total number of adopters: 930000.0
# [-0.23654399  0.06113485  0.80512074  0.05884121]
# [0.02277434 0.01058638 0.01733932 0.0171693 ]
# New adopters at time 1: 117800.0
# New adopters at time 2: 17600.0
# New adopters at time 3: 37800.0
# New adopters at time 4: 97000.0
# New adopters at time 5: 16000.0
# New adopters at time 6: 64400.0
# New adopters at time 7: 73600.0
# New adopters at time 8: 44800.0
# New adopters at time 9: 174200.0
# New adopters at time 10: 74200.0
# New adopters at time 11: 22600.0
# New adopters at time 12: 53600.0
# New adopters at time 13: 41400.0
# New adopters at time 14: 64600.0
# New adopters at time 15: 103200.0
# New adopters at time 16: 87000.0
# Total number of adopters: 1089800.0
# [-0.21376964  0.07172124  0.82246006  0.07601051]
# [-0.02653407 -0.03486402 -0.03298958 -0.03447839]
# New adopters at time 1: 75600.0
# New adopters at time 2: 17600.0
# New adopters at time 3: 21000.0
# New adopters at time 4: 49600.0
# New adopters at time 5: 21000.0
# New adopters at time 6: 34800.0
# New adopters at time 7: 51200.0
# New adopters at time 8: 32400.0
# New adopters at time 9: 83200.0
# New adopters at time 10: 55400.0
# New adopters at time 11: 33000.0
# New adopters at time 12: 48600.0
# New adopters at time 13: 40000.0
# New adopters at time 14: 53200.0
# New adopters at time 15: 77000.0
# New adopters at time 16: 72200.0
# Total number of adopters: 765800.0
# [-0.24030371  0.03685722  0.78947048  0.04153212]
# [0.0405251  0.03774792 0.03856937 0.0354455 ]
# New adopters at time 1: 116400.0
# New adopters at time 2: 18400.0
# New adopters at time 3: 36000.0
# New adopters at time 4: 101800.0
# New adopters at time 5: 18200.0
# New adopters at time 6: 71600.0
# New adopters at time 7: 78400.0
# New adopters at time 8: 42400.0
# New adopters at time 9: 193000.0
# New adopters at time 10: 67000.0
# New adopters at time 11: 23000.0
# New adopters at time 12: 55400.0
# New adopters at time 13: 47600.0
# New adopters at time 14: 64600.0
# New adopters at time 15: 111400.0
# New adopters at time 16: 95400.0
# Total number of adopters: 1140600.0
# [-0.19977861  0.07460514  0.82803985  0.07697761]
# [-0.02724732 -0.02688734 -0.02365994 -0.02654026]

# %%
"""reset Agent_Array"""
Agent_Array=MakeAgentArray(Countypd,Agent_Scale)

pl.plot(Y_tilde.cumsum(axis=0).sum(axis=1),label="Initial model with some start parameters")
pl.plot(Model(params,Timesteps,Agent_Array).cumsum(axis=0).sum(axis=1),label="Model after optimization")
pl.plot(Y_kummulative.sum(axis=1),label="Real dataset")
pl.legend()
pl.plot()
pl.show()
# Out:
# New adopters at time 1: 83200.0
# New adopters at time 2: 15800.0
# New adopters at time 3: 27400.0
# New adopters at time 4: 61800.0
# New adopters at time 5: 22600.0
# New adopters at time 6: 44000.0
# New adopters at time 7: 51000.0
# New adopters at time 8: 36400.0
# New adopters at time 9: 110400.0
# New adopters at time 10: 49400.0
# New adopters at time 11: 25800.0
# New adopters at time 12: 49600.0
# New adopters at time 13: 47400.0
# New adopters at time 14: 62800.0
# New adopters at time 15: 93000.0
# New adopters at time 16: 85800.0
# Total number of adopters: 866400.0

# %% [markdown]
# # Resources
#
# [1] Deffuant, Guillaume, et al. "Mixing beliefs among interacting agents." Advances in Complex Systems 3.01n04 (2000): 87-98.
# [2] Deffuant, Guillaume, et al. "How can extremism prevail? A study based on the relative agreement interaction model." Journal of artificial societies and social simulation 5.4 (2002).
# [3] Kingma, D. P., & Ba, J. (2014). Adam: A method for stochastic optimization. arXiv preprint arXiv:1412.6980.
